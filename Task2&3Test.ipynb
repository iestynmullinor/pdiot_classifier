# %%
GYRO = True
SEQUENCE_LENGTH = 4
SEQUENCE_OVERLAP = 3
BATCH_SIZE = 10
EPOCHS = 50
MODEL_NAME = f"physical_activity_epochs:{EPOCHS}_batch:{BATCH_SIZE}_gyro:{GYRO}_window:{SEQUENCE_LENGTH}_overlap:{SEQUENCE_OVERLAP}.keras"

# %% [markdown]
# # EDIT THE VALUES IN THE CELL ABOVE THEN PRESS RUN ALL

# %%
import file_tagger
import sequence_genrator
import tensorflow as tf
import numpy as np
from keras import layers, Sequential, models
from sklearn.model_selection import train_test_split

# %%
DATA_DIRECTORY = "./all_respeck"
PHYSICAL_ACTIVITIES = {
    "sitting&coughing",
    "sitting&hyperventilating",
    
    "standing&coughing",
    "standing&hyperventilating",
    
    "lying_down_back&coughing",
    "lying_down_back&hyperventilating",
    
    "lying_down_stomach&coughing",
    "lying_down_stomach&hyperventilating",
    
    "lying_down_right&coughing",
    "lying_down_right&hyperventilating",
    
    "lying_down_left&coughing",
    "lying_down_left&hyperventilating",
    
    "sitting&talking",
    "sitting&eating",
    "sitting&singing",
    "sitting&laughing",
    
    "standing&talking",
    "standing&eating",
    "standing&singing",
    "standing&laughing",
    
    "lying_down_back&talking",
    "lying_down_back&singing",
    "lying_down_back&laughing",
    
    "lying_down_right&talking",
    "lying_down_right&singing",
    "lying_down_right&laughing",
    
    "lying_down_left&talking",
    "lying_down_left&singing",
    "lying_down_left&laughing",
    
    "lying_down_stomach&talking",
    "lying_down_stomach&singing",
    "lying_down_stomach&laughing",
}

# %%
def generate_training_data(directory, sequence_length, overlap, gyro = GYRO): # if gyro is false, only accelerometer data is used

    tagged_data = []

    # group each csv file into their respective areas
    csv_dictionary = file_tagger.tag_directory(directory)

    # iterates through each activity
    for key in PHYSICAL_ACTIVITIES:

        # iterates through each csv file for the activity 
        for csv_file in csv_dictionary[key]:
            if gyro:
                sequences = sequence_genrator.generate_sequences_from_file_with_gyroscope(directory + "/" + csv_file, sequence_length, overlap)
            else:
                sequences = sequence_genrator.generate_sequences_from_file_without_gyroscope(directory + "/" + csv_file, sequence_length, overlap)

            # iterate through each generated sequence
            for sequence in sequences:
                tagged_data.append((key, sequence))

    print ("there are " + str(len(tagged_data)) + " tagged sequences in the dataset")
    return tagged_data

# %%
# split data into training, dev, and test sets
def train_dev_test_split(data, labels, dev_size, test_size, random_state=42):
    # Split the data into training and temporary (dev + test) sets
    train_data, temp_data, train_labels, temp_labels = train_test_split(data, labels, test_size=(dev_size + test_size), random_state=random_state)
    
    # Split the temporary data into dev and test sets
    dev_data, test_data, dev_labels, test_labels = train_test_split(temp_data, temp_labels, 
                                                                 test_size=(test_size / (dev_size + test_size)), random_state=random_state)
    
    return train_data, dev_data, test_data, train_labels, dev_labels, test_labels

# %%
tagged_sequences = generate_training_data(DATA_DIRECTORY, SEQUENCE_LENGTH, SEQUENCE_OVERLAP)

# Combine all sequences and labels
sequences = [sequence for _, sequence in tagged_sequences]
labels = [label for label, _ in tagged_sequences]


# encode labels to numbers
sequences = np.array(sequences, dtype=np.float32)
label_to_index = {label: idx for idx, label in enumerate(PHYSICAL_ACTIVITIES)}
labels_encoded = [label_to_index[label] for label in labels]
labels_encoded = np.array(labels_encoded)
# Out:
# there are 38213 tagged sequences in the dataset

# %%
#CNN MODEL
def train_model_CNN(input_data, labels_encoded, unique_labels, epochs, batch_size, validation_data):
    if GYRO:
        width = 6
    else:
        width = 3
    # Define the CNN model for your specific input shape
    model = Sequential([
        layers.Conv1D(32, 3, activation='relu', input_shape=(SEQUENCE_LENGTH*25, width)),
        layers.MaxPooling1D(2),
        layers.Conv1D(64, 3, activation='relu'),
        layers.MaxPooling1D(2),
        layers.Conv1D(64, 3, activation='relu'),
        layers.MaxPooling1D(2),
        layers.Conv1D(128, 3, activation='relu'),
        layers.MaxPooling1D(2),
        layers.Dropout(0.5),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(len(unique_labels), activation='softmax')
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Train the CNN model
    model.fit(input_data, labels_encoded, epochs=epochs, batch_size=batch_size, validation_data=validation_data)

    return model

# %%
train_data, dev_data, test_data, train_labels, dev_labels, test_labels = train_dev_test_split(sequences, labels_encoded, dev_size=0.1, test_size=0.1) #10% dev, 10% test


# train and save model (CHOOSE BETWEEN CNN AND LSTM)
model = train_model_CNN(train_data, train_labels, PHYSICAL_ACTIVITIES, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(dev_data, dev_labels)) #batch_size, epochs


# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(test_data, test_labels)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")

# Save the trained model
model.save(f"models/Task2&3Test/{MODEL_NAME}_{test_accuracy}")
# Out:
# Epoch 1/50
# 3057/3057 [==============================] - 18s 5ms/step - loss: 2.1012 - accuracy: 0.1568 - val_loss: 1.9766 - val_accuracy: 0.1769
# Epoch 2/50
# 3057/3057 [==============================] - 17s 5ms/step - loss: 1.9807 - accuracy: 0.1807 - val_loss: 1.9419 - val_accuracy: 0.1869
# Epoch 3/50
# 3057/3057 [==============================] - 15s 5ms/step - loss: 1.7804 - accuracy: 0.2437 - val_loss: 1.5478 - val_accuracy: 0.3483
# Epoch 4/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.5194 - accuracy: 0.3447 - val_loss: 1.4387 - val_accuracy: 0.3735
# Epoch 5/50
# 3057/3057 [==============================] - 17s 6ms/step - loss: 1.4410 - accuracy: 0.3702 - val_loss: 1.3404 - val_accuracy: 0.3968
# Epoch 6/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.3855 - accuracy: 0.3936 - val_loss: 1.2874 - val_accuracy: 0.4156
# Epoch 7/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.3474 - accuracy: 0.4154 - val_loss: 1.2839 - val_accuracy: 0.4368
# Epoch 8/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.3129 - accuracy: 0.4266 - val_loss: 1.2056 - val_accuracy: 0.4747
# Epoch 9/50
# 3057/3057 [==============================] - 15s 5ms/step - loss: 1.2785 - accuracy: 0.4518 - val_loss: 1.2785 - val_accuracy: 0.4481
# Epoch 10/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.2503 - accuracy: 0.4628 - val_loss: 1.1855 - val_accuracy: 0.4737
# Epoch 11/50
# 3057/3057 [==============================] - 15s 5ms/step - loss: 1.2222 - accuracy: 0.4793 - val_loss: 1.1768 - val_accuracy: 0.4834
# Epoch 12/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.1979 - accuracy: 0.4890 - val_loss: 1.1148 - val_accuracy: 0.5161
# Epoch 13/50
# 3057/3057 [==============================] - 15s 5ms/step - loss: 1.1786 - accuracy: 0.5017 - val_loss: 1.0736 - val_accuracy: 0.5263
# Epoch 14/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.1536 - accuracy: 0.5115 - val_loss: 1.0888 - val_accuracy: 0.5334
# Epoch 15/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.1451 - accuracy: 0.5187 - val_loss: 1.0715 - val_accuracy: 0.5493
# Epoch 16/50
# 3057/3057 [==============================] - 15s 5ms/step - loss: 1.1201 - accuracy: 0.5212 - val_loss: 1.0829 - val_accuracy: 0.5376
# Epoch 17/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.1049 - accuracy: 0.5287 - val_loss: 1.0790 - val_accuracy: 0.5504
# Epoch 18/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.0910 - accuracy: 0.5355 - val_loss: 1.0284 - val_accuracy: 0.5608
# Epoch 19/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.0739 - accuracy: 0.5495 - val_loss: 1.0321 - val_accuracy: 0.5603
# Epoch 20/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.0654 - accuracy: 0.5487 - val_loss: 1.0462 - val_accuracy: 0.5488
# Epoch 21/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.0518 - accuracy: 0.5576 - val_loss: 0.9963 - val_accuracy: 0.5716
# Epoch 22/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.0354 - accuracy: 0.5629 - val_loss: 1.0567 - val_accuracy: 0.5556
# Epoch 23/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.0305 - accuracy: 0.5673 - val_loss: 0.9561 - val_accuracy: 0.5891
# Epoch 24/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.0107 - accuracy: 0.5709 - val_loss: 0.9461 - val_accuracy: 0.5998
# Epoch 25/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 1.0093 - accuracy: 0.5731 - val_loss: 0.9616 - val_accuracy: 0.5894
# Epoch 26/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.9989 - accuracy: 0.5798 - val_loss: 0.9490 - val_accuracy: 0.6019
# Epoch 27/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.9865 - accuracy: 0.5830 - val_loss: 1.0151 - val_accuracy: 0.5645
# Epoch 28/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.9788 - accuracy: 0.5881 - val_loss: 0.9221 - val_accuracy: 0.6022
# Epoch 29/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.9643 - accuracy: 0.5959 - val_loss: 0.9882 - val_accuracy: 0.5836
# Epoch 30/50
# 3057/3057 [==============================] - 17s 5ms/step - loss: 0.9715 - accuracy: 0.5923 - val_loss: 0.9180 - val_accuracy: 0.6203
# Epoch 31/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.9555 - accuracy: 0.5980 - val_loss: 0.9076 - val_accuracy: 0.6161
# Epoch 32/50
# 3057/3057 [==============================] - 17s 6ms/step - loss: 0.9511 - accuracy: 0.6011 - val_loss: 0.9533 - val_accuracy: 0.6111
# Epoch 33/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.9432 - accuracy: 0.6029 - val_loss: 0.8928 - val_accuracy: 0.6203
# Epoch 34/50
# 3057/3057 [==============================] - 17s 5ms/step - loss: 0.9396 - accuracy: 0.6075 - val_loss: 0.8695 - val_accuracy: 0.6305
# Epoch 35/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.9215 - accuracy: 0.6130 - val_loss: 0.9158 - val_accuracy: 0.6106
# Epoch 36/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.9205 - accuracy: 0.6128 - val_loss: 0.8616 - val_accuracy: 0.6464
# Epoch 37/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.9224 - accuracy: 0.6118 - val_loss: 0.8897 - val_accuracy: 0.6244
# Epoch 38/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.9006 - accuracy: 0.6220 - val_loss: 0.8719 - val_accuracy: 0.6381
# Epoch 39/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.9091 - accuracy: 0.6205 - val_loss: 0.8726 - val_accuracy: 0.6318
# Epoch 40/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.9021 - accuracy: 0.6231 - val_loss: 0.8828 - val_accuracy: 0.6352
# Epoch 41/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.8986 - accuracy: 0.6242 - val_loss: 0.8628 - val_accuracy: 0.6239
# Epoch 42/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.8833 - accuracy: 0.6300 - val_loss: 0.8413 - val_accuracy: 0.6443
# Epoch 43/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.8766 - accuracy: 0.6372 - val_loss: 0.8526 - val_accuracy: 0.6485
# Epoch 44/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.8799 - accuracy: 0.6332 - val_loss: 0.9122 - val_accuracy: 0.6221
# Epoch 45/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.8697 - accuracy: 0.6375 - val_loss: 0.8616 - val_accuracy: 0.6328
# Epoch 46/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.8692 - accuracy: 0.6403 - val_loss: 0.8806 - val_accuracy: 0.6320
# Epoch 47/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.8674 - accuracy: 0.6380 - val_loss: 0.8678 - val_accuracy: 0.6391
# Epoch 48/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.8666 - accuracy: 0.6379 - val_loss: 0.8340 - val_accuracy: 0.6430
# Epoch 49/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.8507 - accuracy: 0.6490 - val_loss: 0.8454 - val_accuracy: 0.6430
# Epoch 50/50
# 3057/3057 [==============================] - 16s 5ms/step - loss: 0.8625 - accuracy: 0.6417 - val_loss: 0.8690 - val_accuracy: 0.6381
# 120/120 [==============================] - 0s 3ms/step - loss: 0.8481 - accuracy: 0.6387
# Test Loss: 0.848096489906311, Test Accuracy: 0.6386708617210388
# 2023-11-05 03:58:05.691869: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,5,128]
# 	 [[{{node inputs}}]]
# 2023-11-05 03:58:06.223681: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,5,128]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/Task2&3Test/physical_activity_epochs:50_batch:10_gyro:False_window:5_overlap:4.keras_0.6386708617210388/assets
# INFO:tensorflow:Assets written to: models/Task2&3Test/physical_activity_epochs:50_batch:10_gyro:False_window:5_overlap:4.keras_0.6386708617210388/assets
